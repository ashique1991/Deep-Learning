# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stock_ALL_AX = ["ALL.AX"]
stock_ANZ_AX = ['ANZ.AX']
stock_BHP_AX = ['BHP.AX']
stock_CBA_AX = ['CBA.AX']
stock_CSL_AX = ['CSL.AX']
stock_FMG_AX = ['FMG.AX']
stock_GMG_AX = ['GMG.AX']
stock_MQG_AX = ['MQG.AX']
stock_NAB_AX = ['NAB.AX']
stock_NCM_AX = ['NCM.AX']
stock_REA_AX = ['REA.AX']
stock_RIO_AX = ['RIO.AX']
stock_TCL_AX = ['TCL.AX']
stock_TLS_AX = ['TLS.AX']
stock_WBC_AX = ['WBC.AX']
stock_WES_AX = ['WES.AX']

# %%
start_date = '2006-01-01'
end_date = '2023-01-01'

# %%
ALL_AX = yf.download(stock_ALL_AX, start=start_date, end=end_date)
ANZ_AX = yf.download(stock_ANZ_AX, start=start_date, end=end_date)
BHP_AX = yf.download(stock_BHP_AX, start=start_date, end=end_date)
CBA_AX = yf.download(stock_CBA_AX, start=start_date, end=end_date)
CSL_AX = yf.download(stock_CSL_AX, start=start_date, end=end_date)
FMG_AX = yf.download(stock_FMG_AX, start=start_date, end=end_date)
GMG_AX = yf.download(stock_GMG_AX, start=start_date, end=end_date)
MQG_AX = yf.download(stock_MQG_AX, start=start_date, end=end_date)
NAB_AX = yf.download(stock_NAB_AX, start=start_date, end=end_date)
NCM_AX = yf.download(stock_NCM_AX, start=start_date, end=end_date)
REA_AX = yf.download(stock_REA_AX, start=start_date, end=end_date)
RIO_AX = yf.download(stock_RIO_AX, start=start_date, end=end_date)
TCL_AX = yf.download(stock_TCL_AX, start=start_date, end=end_date)
TLS_AX = yf.download(stock_TLS_AX, start=start_date, end=end_date)
WBC_AX = yf.download(stock_WBC_AX, start=start_date, end=end_date)
WES_AX = yf.download(stock_WES_AX, start=start_date, end=end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %% [markdown]
# # Data Processing

# %%
# select and rename columns of Aristocrat Leisure Ltd (ALL_AX)
column_name = ['Close','Volume']
ALL_AX_select = ALL_AX[column_name]
column_mapping = {
    'Close': 'ALL_AX Close',
    'Volume': 'ALL_AX Volume'
}
ALL_AX_final = ALL_AX_select.rename(columns=column_mapping)

# %%
# select and rename columns of Australia and New Zealand Banking Group Ltd(ANZ_AX)
column_name = ['Close','Volume']
ANZ_AX_select = ANZ_AX[column_name]
column_mapping = {
    'Close': 'ANZ_AX Close',
    'Volume': 'ANZ_AX Volume'
}
ANZ_AX_final = ALL_AX_select.rename(columns=column_mapping)

# %%
# select and rename columns of BHP Group Ltd (BHP_AX)
column_name = ['Close','Volume']
BHP_AX_select = BHP_AX[column_name]
column_mapping = {
    'Close': 'BHP_AX Close',
    'Volume': 'BHP_AX Volume'
}
BHP_AX_final = BHP_AX_select.rename(columns=column_mapping)

# %%
# select and rename columns of Commonwealth Bank of Australia (CBA_AX)
column_name = ['Close','Volume']
CBA_AX_select = BHP_AX[column_name]
column_mapping = {
    'Close': 'CBA_AX Close',
    'Volume': 'CBA_AX Volume'
}
CBA_AX_final = CBA_AX_select.rename(columns=column_mapping)

# %%
# select and rename columns of CSL Ltd (CSL_AX)
column_name = ['Close','Volume']
CSL_AX_select = CSL_AX[column_name]
column_mapping = {
    'Close': 'CSL_AX Close',
    'Volume': 'CSL_AX Volume'
}
CSL_AX_final = CBA_AX_select.rename(columns=column_mapping)

# %%
# select and rename columns of Fortescue Metals Group Ltd (FMG_AX)
column_name = ['Close','Volume']
FMG_AX_select = FMG_AX[column_name]
column_mapping = {
    'Close': 'FMG_AX Close',
    'Volume': 'FMG_AX Volume'
}
FMG_AX_final = FMG_AX_select.rename(columns=column_mapping)

# %%
# select and rename columns of Goodman Group (GMG_AX)
column_name = ['Close','Volume']
GMG_AX_select = FMG_AX[column_name]
column_mapping = {
    'Close': 'GMG_AX Close',
    'Volume': 'GMG_AX Volume'
}
GMG_AX_final = GMG_AX_select.rename(columns=column_mapping)

# %%
# select and rename columns of Macquarie Group Ltd (MQG_AX)
column_name = ['Close','Volume']
MQG_AX_select = MQG_AX[column_name]
column_mapping = {
    'Close': 'MQG_AX Close',
    'Volume': 'MQG_AX Volume'
}
MQG_AX_final = MQG_AX_select.rename(columns=column_mapping)

# %%
# select and rename columns of National Australia Bank Ltd (NAB_AX)
column_name = ['Close','Volume']
NAB_AX_select = NAB_AX[column_name]
column_mapping = {
    'Close': 'NAB_AX Close',
    'Volume': 'NAB_AX Volume'
}
NAB_AX_final = NAB_AX_select.rename(columns=column_mapping)

# %%
# select and rename columns of Newcrest Mining Ltd (NCM_AX)
column_name = ['Close','Volume']
NCM_AX_select = NAB_AX[column_name]
column_mapping = {
    'Close': 'NCM_AX Close',
    'Volume': 'NCM_AX Volume'
}
NCM_AX_final = NCM_AX_select.rename(columns=column_mapping)

# %%
# select and rename columns of REA Group Ltd (REA_AX)
column_name = ['Close','Volume']
REA_AX_select = REA_AX[column_name]
column_mapping = {
    'Close': 'REA_AX Close',
    'Volume': 'REA_AX Volume'
}
REA_AX_final = REA_AX_select.rename(columns=column_mapping)

# %%
# select and rename columns of RIO Tinto Ltd (RIO_AX)
column_name = ['Close','Volume']
RIO_AX_select = RIO_AX[column_name]
column_mapping = {
    'Close': 'RIO_AX Close',
    'Volume': 'RIO_AX Volume'
}
RIO_AX_final = RIO_AX_select.rename(columns=column_mapping)

# %%
# select and rename columns of Transurban Group (TCL_AX)
column_name = ['Close','Volume']
TCL_AX_select = TCL_AX[column_name]
column_mapping = {
    'Close': 'TCL_AX Close',
    'Volume': 'TCL_AX Volume'
}
TCL_AX_final = TCL_AX_select.rename(columns=column_mapping)

# %%
# select and rename columns of Transurban Group (TCL_AX)
column_name = ['Close','Volume']
TLS_AX_select = TLS_AX[column_name]
column_mapping = {
    'Close': 'TLS_AX Close',
    'Volume': 'TLS_AX Volume'
}
TLS_AX_final = TLS_AX_select.rename(columns=column_mapping)

# %%
# select and rename columns of Westpac Banking Corporation (WBC_AX)
column_name = ['Close','Volume']
WBC_AX_select = WBC_AX[column_name]
column_mapping = {
    'Close': 'WBC_AX Close',
    'Volume': 'WBC_AX Volume'
}
WBC_AX_final = WBC_AX_select.rename(columns=column_mapping)

# %%
# select and rename columns of Wesfarmers Ltd (WES_AX)
column_name = ['Close','Volume']
WES_AX_select = WES_AX[column_name]
column_mapping = {
    'Close': 'WES_AX Close',
    'Volume': 'WES_AX Volume'
}
WES_AX_final = WES_AX_select.rename(columns=column_mapping)
WES_AX_final.head()
# Out:
#             WES_AX Close  WES_AX Volume
# Date
# 2006-01-03     24.876410         432274
# 2006-01-04     24.997595         660594
# 2006-01-05     24.943733         509136
# 2006-01-06     24.391672        2180842
# 2006-01-09     24.283955        1365334

# %%
all_stocks = pd.concat([ALL_AX_final, ANZ_AX_final,BHP_AX_final,CBA_AX_final,CSL_AX_final,FMG_AX_final,GMG_AX_final,MQG_AX_final,NAB_AX_final,NCM_AX_final,REA_AX_final,RIO_AX_final,TCL_AX_final,TLS_AX_final,WBC_AX_final,WES_AX_final], axis=1)
all_stocks.head()
# Out:
#             ALL_AX Close  ALL_AX Volume  ANZ_AX Close  ANZ_AX Volume  \
# Date
# 2006-01-03         12.20         349328         12.20         349328
# 2006-01-04         12.18         721189         12.18         721189
# 2006-01-05         12.20        1186380         12.20        1186380
# 2006-01-06         12.16         899637         12.16         899637
# 2006-01-09         12.24         325104         12.24         325104
#
#             BHP_AX Close  BHP_AX Volume  CBA_AX Close  CBA_AX Volume  \
# Date
# 2006-01-03     21.660353        7280093     21.660353        7280093
# 2006-01-04     22.286428       16274002     22.286428       16274002
# 2006-01-05     22.052818       11436552     22.052818       11436552
# 2006-01-06     21.819208        7104800     21.819208        7104800
# 2006-01-09     22.482660       14577664     22.482660       14577664
#
#             CSL_AX Close  CSL_AX Volume  ...  RIO_AX Close  RIO_AX Volume  \
# ...

# %%
len(all_stocks)
# Out:
# 4299

# %%
# Dealing with the missing values with pandas fillna function (Interpolation-"nearest" Method)
